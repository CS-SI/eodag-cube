# %% [markdown]
# # `to_xarray` method
# This Notebook demonstrates how the `to_xarray` method performs with various types of data and providers.

# %%
from eodag import EODataAccessGateway

dag = EODataAccessGateway()

# %% [markdown]
# ## Netcdf data from `cop_cds`
#
# File is read remotely from http using `h5netcdf`

# %%
prods = dag.search(
    provider="cop_cds",
    productType="ERA5_SL",
    start="2024-01-01",
    end="2024-01-02",
    **{"ecmwf:data_format": "netcdf", "ecmwf:download_format": "unarchived"},
)
xd_nc = prods[0].to_xarray()
xd_nc
# Out:
# [Retry #1] Waiting 11.999981s until next order status check (retry every 0.2' for 10')
# {'data': <xarray.Dataset> Size: 8MB
# Dimensions:     (valid_time: 2, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 16B 2024-01-01 2024-01-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      (valid_time) <U4 32B ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 8MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-12-12T09:39 GRIB to CDM+CF via cfgrib-0.9.1...}

# %% [markdown]
# ## Grib data from `dedl`
#
# File is read locally after download using `cfgrib` (this engine does not handle remote data)

# %%
prods = dag.search(provider="dedl", productType="DT_CLIMATE_ADAPTATION", start="2025-01-01", end="2025-01-02")
xd_grib = prods[0].to_xarray()
xd_grib
# Out:
# [Retry #1] Waiting 11.99994s until next order status check (retry every 0.2' for 10')
# 0.00B [00:00, ?B/s]
# {'DT_CLIMATE_ADAPTATION_20250101_20250102_13fd13a864200602c913d6711d68e24407e49884.grib': <xarray.Dataset> Size: 503MB
# Dimensions:            (time: 2, values: 12582912)
# Coordinates:
#   * time               (time) datetime64[ns] 16B 2025-01-01 2025-01-02
#     step               timedelta64[ns] 8B ...
#     surface            float64 8B ...
#     latitude           (values) float64 101MB ...
#     longitude          (values) float64 101MB ...
#     valid_time         (time) datetime64[ns] 16B ...
#     heightAboveGround  float64 8B ...
# Dimensions without coordinates: values
# Data variables:
#     sp                 (time, values) float32 101MB ...
#     u10                (time, values) float32 101MB ...
#     v10                (time, values) float32 101MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          1003
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-12-12T16:19 GRIB to CDM+CF via cfgrib-0.9.1...}

# %% [markdown]
# ## Raster data from `creodias_s3`
#
# File is read remotely from s3 using `rasterio`

# %%
prods = dag.search(
    provider="creodias_s3", productType="S2_MSI_L2A", start="2024-01-01", end="2024-01-02", items_per_page=1
)
xd_s3_s2 = prods[0].to_xarray()
xd_s3_s2
# Out:
# <XarrayDict> (65)
# {'AOT_10m': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'AOT_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'AOT_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B01': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B01_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B02': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'B02_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B02_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B03': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'B03_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B03_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B04': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'B04_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B04_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B05': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B05_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B06': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B06_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B07': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B07_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B08': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'B09': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B11': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B11_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B12': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B12_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'B8A': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'B8A_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'MSK_CLASSI_B00': <xarray.Dataset> (band: 3, x: 1830, y: 1830) Size: 40MB,
# 'MSK_CLDPRB_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_CLDPRB_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'MSK_DETFOO_B01': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'MSK_DETFOO_B02': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'MSK_DETFOO_B03': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'MSK_DETFOO_B04': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'MSK_DETFOO_B05': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_DETFOO_B06': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_DETFOO_B07': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_DETFOO_B08': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'MSK_DETFOO_B09': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'MSK_DETFOO_B10': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'MSK_DETFOO_B11': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_DETFOO_B12': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_DETFOO_B8A': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_QUALIT_B01': <xarray.Dataset> (band: 8, x: 1830, y: 1830) Size: 107MB,
# 'MSK_QUALIT_B02': <xarray.Dataset> (band: 8, x: 10980, y: 10980) Size: 4GB,
# 'MSK_QUALIT_B03': <xarray.Dataset> (band: 8, x: 10980, y: 10980) Size: 4GB,
# 'MSK_QUALIT_B04': <xarray.Dataset> (band: 8, x: 10980, y: 10980) Size: 4GB,
# 'MSK_QUALIT_B05': <xarray.Dataset> (band: 8, x: 5490, y: 5490) Size: 965MB,
# 'MSK_QUALIT_B06': <xarray.Dataset> (band: 8, x: 5490, y: 5490) Size: 965MB,
# 'MSK_QUALIT_B07': <xarray.Dataset> (band: 8, x: 5490, y: 5490) Size: 965MB,
# 'MSK_QUALIT_B08': <xarray.Dataset> (band: 8, x: 10980, y: 10980) Size: 4GB,
# 'MSK_QUALIT_B09': <xarray.Dataset> (band: 8, x: 1830, y: 1830) Size: 107MB,
# 'MSK_QUALIT_B10': <xarray.Dataset> (band: 8, x: 1830, y: 1830) Size: 107MB,
# 'MSK_QUALIT_B11': <xarray.Dataset> (band: 8, x: 5490, y: 5490) Size: 965MB,
# 'MSK_QUALIT_B12': <xarray.Dataset> (band: 8, x: 5490, y: 5490) Size: 965MB,
# 'MSK_QUALIT_B8A': <xarray.Dataset> (band: 8, x: 5490, y: 5490) Size: 965MB,
# 'MSK_SNWPRB_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'MSK_SNWPRB_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'PVI': <xarray.Dataset> (band: 3, x: 343, y: 343) Size: 1MB,
# 'SCL_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'SCL_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB,
# 'WVP_10m': <xarray.Dataset> (band: 1, x: 10980, y: 10980) Size: 482MB,
# 'WVP_20m': <xarray.Dataset> (band: 1, x: 5490, y: 5490) Size: 121MB,
# 'WVP_60m': <xarray.Dataset> (band: 1, x: 1830, y: 1830) Size: 13MB}

# %% [markdown]
# ## Errors raised when xarray.Dataset creation is not possible

# %%
prods[0].assets["MTD_DS.xml"].to_xarray()
# Out:
# 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# DatasetCreationError                      Traceback (most recent call last)
# File ~/workspace/eodag-cube/eodag_cube/api/product/_product.py:378, in EOProduct.to_xarray(self, asset_key, wait, timeout, roles, **xarray_kwargs)
#     377 with rasterio.Env(**gdal_env):
# --> 378     ds = try_open_dataset(file, **xarray_kwargs)
#     379 return XarrayDict({asset_key or "data": ds})
#
# File ~/workspace/eodag-cube/eodag_cube/utils/xarray.py:128, in try_open_dataset(file, **xarray_kwargs)
#     126         return ds
# --> 128 raise DatasetCreationError(
#     129     f"None of the engines {engines} could open the dataset at {file.path}."
#     130 )
#
# DatasetCreationError: None of the engines ['h5netcdf', 'scipy', 'rasterio', 'store'] could open the dataset at eodata/Sentinel-2/MSI/L2A/2024/01/01/S2B_MSIL2A_20240101T000749_N0510_R130_T49CDQ_20240101T011530.SAFE/DATASTRIP/DS_2BPS_20240101T011530_S20240101T000755/MTD_DS.xml.
#
# During handling of the above exception, another exception occurred:
#
# DatasetCreationError                      Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 prods[0].assets["MTD_DS.xml"].to_xarray()
#
# File ~/workspace/eodag-cube/eodag_cube/api/product/_assets.py:131, in Asset.to_xarray(self, wait, timeout, **xarray_kwargs)
#     119 def to_xarray(self, wait: float = DEFAULT_DOWNLOAD_WAIT, timeout: float = DEFAULT_DOWNLOAD_TIMEOUT,
#     120               **xarray_kwargs: Mapping[str, Any]) -> xr.Dataset:
#     121     """
#     122     Return asset data as a :class:`xarray.Dataset`.
#     123
#    (...)
#     129     :returns: Asset data as a :class:`xarray.Dataset`
#     130     """
# --> 131     xd = self.product.to_xarray(self.key, wait, timeout, **xarray_kwargs)
#     132     if len(xd) > 1:
#     133         logger.warning(f"Several Datasets were returned for {self.product} {self.key}: {xd.keys()}")
#
# File ~/workspace/eodag-cube/eodag_cube/api/product/_product.py:408, in EOProduct.to_xarray(self, asset_key, wait, timeout, roles, **xarray_kwargs)
#     406 xd = build_local_xarray_dict(path, **xarray_kwargs)
#     407 if not xd:
# --> 408     raise DatasetCreationError(
#     409         f"Could not build local XarrayDict for {self} {asset_key if asset_key else ''}"
#     410     )
#     411 return xd
#
# DatasetCreationError: Could not build local XarrayDict for EOProduct(id=S2B_MSIL2A_20240101T000749_N0510_R130_T49CDQ_20240101T011530, provider=creodias_s3) MTD_DS.xml
