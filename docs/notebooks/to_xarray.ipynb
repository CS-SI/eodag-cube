# %% [markdown]
# # `to_xarray` method
# This Notebook demonstrates how the `to_xarray` method performs with various types of data and providers.

# %%
from eodag import EODataAccessGateway

dag = EODataAccessGateway()

# %% [markdown]
# ## Netcdf data from `cop_cds`
#
# File is read remotely from http using `h5netcdf`

# %%
prods = dag.search(
    provider="cop_cds",
    productType="ERA5_SL",
    start="2024-01-01",
    end="2024-01-02",
    **{"ecmwf:data_format": "netcdf", "ecmwf:download_format": "unarchived"}
)
xd_nc = prods[0].to_xarray()
xd_nc
# Out:
# [Retry #1] Waiting 11.999981s until next order status check (retry every 0.2' for 10')
# {'data': <xarray.Dataset> Size: 8MB
# Dimensions:     (valid_time: 2, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 16B 2024-01-01 2024-01-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      (valid_time) <U4 32B ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 8MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-12-12T09:39 GRIB to CDM+CF via cfgrib-0.9.1...}

# %% [markdown]
# ## Grib data from `dedl`
#
# File is read locally after download using `cfgrib` (this engine does not handle remote data)

# %%
prods = dag.search(
    provider="dedl",
    productType="DT_CLIMATE_ADAPTATION",
    start="2025-01-01",
    end="2025-01-02"
)
xd_grib = prods[0].to_xarray()
xd_grib
# Out:
# [Retry #1] Waiting 11.99994s until next order status check (retry every 0.2' for 10')
# 0.00B [00:00, ?B/s]
# {'DT_CLIMATE_ADAPTATION_20250101_20250102_13fd13a864200602c913d6711d68e24407e49884.grib': <xarray.Dataset> Size: 503MB
# Dimensions:            (time: 2, values: 12582912)
# Coordinates:
#   * time               (time) datetime64[ns] 16B 2025-01-01 2025-01-02
#     step               timedelta64[ns] 8B ...
#     surface            float64 8B ...
#     latitude           (values) float64 101MB ...
#     longitude          (values) float64 101MB ...
#     valid_time         (time) datetime64[ns] 16B ...
#     heightAboveGround  float64 8B ...
# Dimensions without coordinates: values
# Data variables:
#     sp                 (time, values) float32 101MB ...
#     u10                (time, values) float32 101MB ...
#     v10                (time, values) float32 101MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          1003
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-12-12T16:19 GRIB to CDM+CF via cfgrib-0.9.1...}

# %% [markdown]
# ## Raster data from `creodias_s3`
#
# File is read remotely from s3 using `rasterio`

# %%
prods = dag.search(
    provider="creodias_s3",
    productType="S2_MSI_L2A",
    start="2024-01-01",
    end="2024-01-02",
    items_per_page=1
)
xd_s3_s2 = prods[0].to_xarray()
xd_s3_s2
# Out:
# {'T49CDQ_20240101T000749_AOT_10m.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 241MB
# [120560400 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B08_10m.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 241MB
# [120560400 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_WVP_10m.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 241MB
# [120560400 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B02_10m.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 241MB
# [120560400 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B05_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B04_10m.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 241MB
# [120560400 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B03_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B01_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_AOT_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B06_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B11_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B04_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B02_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B07_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_TCI_10m.jp2': <xarray.DataArray (band: 3, y: 10980, x: 10980)> Size: 362MB
# [361681200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B03_10m.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 241MB
# [120560400 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_WVP_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_SCL_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B8A_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_AOT_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B03_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B02_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B04_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B06_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B11_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B09_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B07_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_TCI_20m.jp2': <xarray.DataArray (band: 3, y: 5490, x: 5490)> Size: 90MB
# [90420300 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B01_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B12_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 60MB
# [30140100 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B05_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B12_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_B8A_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_SCL_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 3MB
# [3348900 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_TCI_60m.jp2': <xarray.DataArray (band: 3, y: 1830, x: 1830)> Size: 10MB
# [10046700 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_WVP_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 7MB
# [3348900 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_CLASSI_B00.jp2': <xarray.DataArray (band: 3, y: 1830, x: 1830)> Size: 10MB
# [10046700 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_CLDPRB_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B01.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 3MB
# [3348900 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_CLDPRB_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 3MB
# [3348900 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B04.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 121MB
# [120560400 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B05.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B06.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B03.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 121MB
# [120560400 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B07.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B02.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 121MB
# [120560400 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B08.jp2': <xarray.DataArray (band: 1, y: 10980, x: 10980)> Size: 121MB
# [120560400 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B09.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 3MB
# [3348900 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B10.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 3MB
# [3348900 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B11.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B8A.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_DETFOO_B12.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B01.jp2': <xarray.DataArray (band: 8, y: 1830, x: 1830)> Size: 27MB
# [26791200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B03.jp2': <xarray.DataArray (band: 8, y: 10980, x: 10980)> Size: 964MB
# [964483200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B06.jp2': <xarray.DataArray (band: 8, y: 5490, x: 5490)> Size: 241MB
# [241120800 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B02.jp2': <xarray.DataArray (band: 8, y: 10980, x: 10980)> Size: 964MB
# [964483200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B04.jp2': <xarray.DataArray (band: 8, y: 10980, x: 10980)> Size: 964MB
# [964483200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B09.jp2': <xarray.DataArray (band: 8, y: 1830, x: 1830)> Size: 27MB
# [26791200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B05.jp2': <xarray.DataArray (band: 8, y: 5490, x: 5490)> Size: 241MB
# [241120800 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B12.jp2': <xarray.DataArray (band: 8, y: 5490, x: 5490)> Size: 241MB
# [241120800 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B10.jp2': <xarray.DataArray (band: 8, y: 1830, x: 1830)> Size: 27MB
# [26791200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B08.jp2': <xarray.DataArray (band: 8, y: 10980, x: 10980)> Size: 964MB
# [964483200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 88kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 88kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B07.jp2': <xarray.DataArray (band: 8, y: 5490, x: 5490)> Size: 241MB
# [241120800 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B11.jp2': <xarray.DataArray (band: 8, y: 5490, x: 5490)> Size: 241MB
# [241120800 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_QUALIT_B8A.jp2': <xarray.DataArray (band: 8, y: 5490, x: 5490)> Size: 241MB
# [241120800 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 64B 1 2 3 4 5 6 7 8
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_SNWPRB_20m.jp2': <xarray.DataArray (band: 1, y: 5490, x: 5490)> Size: 30MB
# [30140100 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 44kB 4e+05 4e+05 4e+05 ... 5.097e+05 5.098e+05
#   * y            (y) float64 44kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'MSK_SNWPRB_60m.jp2': <xarray.DataArray (band: 1, y: 1830, x: 1830)> Size: 3MB
# [3348900 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 4e+05 4e+05 4.001e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 15kB 1.5e+06 1.5e+06 1.5e+06 ... 1.39e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0, 'T49CDQ_20240101T000749_PVI.jp2': <xarray.DataArray (band: 3, y: 343, x: 343)> Size: 353kB
# [352947 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 3kB 4.001e+05 4.004e+05 ... 5.092e+05 5.096e+05
#   * y            (y) float64 3kB 1.5e+06 1.5e+06 ... 1.391e+06 1.39e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0}
